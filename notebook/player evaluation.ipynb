# %% [markdown]
# # importing libraries

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from category_encoders import BinaryEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, OrdinalEncoder , OneHotEncoder
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Read data

# %%
df15 = pd.read_csv("F:\AI corse\\final project\sources\players_15.csv")
# Out:
# C:\Users\HP.SXS04\AppData\Local\Temp\ipykernel_15580\3321822958.py:1: DtypeWarning: Columns (104) have mixed types. Specify dtype option on import or set low_memory=False.
#   df15 = pd.read_csv("F:\AI corse\\final project\sources\players_15.csv")

# %%
df16 = pd.read_csv("F:\AI corse\\final project\sources\players_16.csv")
# Out:
# C:\Users\HP.SXS04\AppData\Local\Temp\ipykernel_15580\1907900780.py:1: DtypeWarning: Columns (104) have mixed types. Specify dtype option on import or set low_memory=False.
#   df16 = pd.read_csv("F:\AI corse\\final project\sources\players_16.csv")

# %%
df17 = pd.read_csv("F:\AI corse\\final project\sources\players_17.csv")

# %%
df18 = pd.read_csv("F:\AI corse\\final project\sources\players_18.csv")
# Out:
# C:\Users\HP.SXS04\AppData\Local\Temp\ipykernel_15580\270566522.py:1: DtypeWarning: Columns (81,82,83,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   df18 = pd.read_csv("F:\AI corse\\final project\sources\players_18.csv")

# %%
df19 = pd.read_csv("F:\AI corse\\final project\sources\players_19.csv")

# %%
df20 = pd.read_csv("F:\AI corse\\final project\sources\players_20.csv")

# %%
df21 = pd.read_csv("F:\AI corse\\final project\sources\players_21.csv")

# %%
df22 = pd.read_csv("F:\AI corse\\final project\sources\players_22.csv")
# Out:
# C:\Users\HP.SXS04\AppData\Local\Temp\ipykernel_15580\363958674.py:1: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df22 = pd.read_csv("F:\AI corse\\final project\sources\players_22.csv")

# %% [markdown]
# # Compine the data

# %%
df =pd.concat([df15,df16,df17,df18,df19,df20,df21,df22])

# %%
df.shape
# Out:
# (142079, 110)

# %%
df.reset_index(inplace =True)

# %%
df.drop('index' , axis = 1 , inplace= True)

# %% [markdown]
# ## data analysis

# %%
top_clubs = df15.groupby(['club_name']).overall.mean().sort_values(ascending  = False)[:20]
px.bar( top_clubs,  x= top_clubs.index , y = top_clubs.values , color_discrete_sequence = ['blue'] , title= "Top 20 club in FI15"  )

# %%
top_players = df15[['short_name', 'overall']][:20]
px.bar( top_players,  x= "short_name" , y = "overall" , color_discrete_sequence = ['blue'] , title= "Top 20 player in FI15"  )

# %%
potential = df15[['short_name', "potential"]].sort_values(by = ['potential'], ascending = False)[:20]
px.bar( potential,  x= "short_name" , y = "potential" , color_discrete_sequence = ['blue'] , title= "Top 20 potental in FI15"  )

# %%
top_league_wage= df15[['league_name', 'wage_eur']].groupby('league_name').count().sort_values(by='wage_eur' ,ascending= False)[0:20]
px.bar(top_league_wage ,color_discrete_sequence = ['blue'])

# %%
top_league_value= df15[['league_name', 'value_eur']].groupby('league_name').count().sort_values(by='value_eur' ,ascending= False)[0:20]
px.bar(top_league_value ,color_discrete_sequence = ['blue'])

# %%
average_age = df15[['league_name', 'age']].groupby('league_name').mean().sort_values(by=["age"] ,ascending= False)[0:20]
px.bar(average_age ,color_discrete_sequence = ['blue'])

# %% [markdown]
# # Data summary report

# %%
#from pandas_profiling import ProfileReport

# %%
##profile = ProfileReport(df)
#profile.to_file("summary report.html")

# %% [markdown]
# # Data first look

# %%
df
# Out:
#         sofifa_id                                         player_url  \
# 0          158023  https://sofifa.com/player/158023/lionel-messi/...
# 1           20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2            9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3           41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4          167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...           ...                                                ...
# 142074     261962  https://sofifa.com/player/261962/defu-song/220002
# 142075     262040  https://sofifa.com/player/262040/caoimhin-port...
# 142076     262760  https://sofifa.com/player/262760/nathan-logue/...
# 142077     262820  https://sofifa.com/player/262820/luke-rudden/2...
# 142078     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                 short_name                            long_name  \
# 0                 L. Messi       Lionel Andrés Messi Cuccittini
# 1        Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 2                A. Robben                         Arjen Robben
# 3           Z. Ibrahimović                   Zlatan Ibrahimović
# 4                 M. Neuer                   Manuel Peter Neuer
# ...                    ...                                  ...
# 142074           Song Defu                                  宋德福
# 142075           C. Porter                      Caoimhin Porter
# 142076            N. Logue              Nathan Logue-Cunningham
# 142077           L. Rudden                          Luke Rudden
# 142078  E. Lalchhanchhuaha              Emanuel Lalchhanchhuaha
#
#        player_positions  overall  potential    value_eur  wage_eur  age  ...  \
# 0                    CF       93         95  100500000.0  550000.0   27  ...
# 1                LW, LM       92         92   79000000.0  375000.0   29  ...
# 2            RM, LM, RW       90         90   54500000.0  275000.0   30  ...
# 3                    ST       90         90   52500000.0  275000.0   32  ...
# 4                    GK       90         90   63500000.0  300000.0   28  ...
# ...                 ...      ...        ...          ...       ...  ...  ...
# 142074              CDM       47         52      70000.0    1000.0   22  ...
# 142075               CM       47         59     110000.0     500.0   19  ...
# 142076               CM       47         55     100000.0     500.0   21  ...
# 142077               ST       47         60     110000.0     500.0   19  ...
# 142078              CAM       47         60     110000.0     500.0   19  ...
#
#          lcb    cb   rcb    rb    gk  \
# 0       45+3  45+3  45+3  54+3  15+3
# 1       52+3  52+3  52+3  57+3  16+3
# 2       46+3  46+3  46+3  55+3  14+3
# 3       55+3  55+3  55+3  56+3  17+3
# 4       38+3  38+3  38+3  36+3  87+3
# ...      ...   ...   ...   ...   ...
# 142074  46+2  46+2  46+2  48+2  15+2
# 142075  44+2  44+2  44+2  48+2  14+2
# 142076  45+2  45+2  45+2  47+2  12+2
# 142077  26+2  26+2  26+2  32+2  15+2
# 142078  41+2  41+2  41+2  45+2  16+2
#
#                                           player_face_url  \
# 0       https://cdn.sofifa.net/players/158/023/15_120.png
# 1       https://cdn.sofifa.net/players/020/801/15_120.png
# 2       https://cdn.sofifa.net/players/009/014/15_120.png
# 3       https://cdn.sofifa.net/players/041/236/15_120.png
# 4       https://cdn.sofifa.net/players/167/495/15_120.png
# ...                                                   ...
# 142074  https://cdn.sofifa.net/players/261/962/22_120.png
# 142075  https://cdn.sofifa.net/players/262/040/22_120.png
# 142076  https://cdn.sofifa.net/players/262/760/22_120.png
# 142077  https://cdn.sofifa.net/players/262/820/22_120.png
# 142078  https://cdn.sofifa.net/players/264/540/22_120.png
#
#                                      club_logo_url  \
# 0          https://cdn.sofifa.net/teams/241/60.png
# 1          https://cdn.sofifa.net/teams/243/60.png
# 2           https://cdn.sofifa.net/teams/21/60.png
# 3           https://cdn.sofifa.net/teams/73/60.png
# 4           https://cdn.sofifa.net/teams/21/60.png
# ...                                            ...
# 142074  https://cdn.sofifa.net/teams/112541/60.png
# 142075     https://cdn.sofifa.net/teams/445/60.png
# 142076  https://cdn.sofifa.net/teams/111131/60.png
# 142077  https://cdn.sofifa.net/teams/111131/60.png
# 142078  https://cdn.sofifa.net/teams/113040/60.png
#
#                               club_flag_url  \
# 0       https://cdn.sofifa.net/flags/es.png
# 1       https://cdn.sofifa.net/flags/es.png
# 2       https://cdn.sofifa.net/flags/de.png
# 3       https://cdn.sofifa.net/flags/fr.png
# 4       https://cdn.sofifa.net/flags/de.png
# ...                                     ...
# 142074  https://cdn.sofifa.net/flags/cn.png
# 142075  https://cdn.sofifa.net/flags/ie.png
# 142076  https://cdn.sofifa.net/flags/ie.png
# 142077  https://cdn.sofifa.net/flags/ie.png
# 142078  https://cdn.sofifa.net/flags/in.png
#
#                                    nation_logo_url  \
# 0         https://cdn.sofifa.net/teams/1369/60.png
# 1         https://cdn.sofifa.net/teams/1354/60.png
# 2       https://cdn.sofifa.net/teams/105035/60.png
# 3         https://cdn.sofifa.net/teams/1363/60.png
# 4         https://cdn.sofifa.net/teams/1337/60.png
# ...                                            ...
# 142074                                         NaN
# 142075                                         NaN
# 142076                                         NaN
# 142077                                         NaN
# 142078                                         NaN
#
#                             nation_flag_url
# 0       https://cdn.sofifa.net/flags/ar.png
# 1       https://cdn.sofifa.net/flags/pt.png
# 2       https://cdn.sofifa.net/flags/nl.png
# 3       https://cdn.sofifa.net/flags/se.png
# 4       https://cdn.sofifa.net/flags/de.png
# ...                                     ...
# 142074  https://cdn.sofifa.net/flags/cn.png
# 142075  https://cdn.sofifa.net/flags/ie.png
# 142076  https://cdn.sofifa.net/flags/ie.png
# 142077  https://cdn.sofifa.net/flags/ie.png
# 142078  https://cdn.sofifa.net/flags/in.png
#
# [142079 rows x 110 columns]

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name',
#        'player_positions', 'overall', 'potential', 'value_eur', 'wage_eur',
#        'age',
#        ...
#        'lcb', 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url',
#        'club_flag_url', 'nation_logo_url', 'nation_flag_url'],
#       dtype='object', length=110)

# %%
df.work_rate.value_counts().index[0:150].sort_values(ascending=True)
# Out:
# Index(['High/High', 'High/Low', 'High/Medium', 'Low/High', 'Low/Low',
#        'Low/Medium', 'Medium/High', 'Medium/Low', 'Medium/Medium'],
#       dtype='object')

# %%
df.describe()
# Out:
#            sofifa_id        overall      potential     value_eur  \
# count  142079.000000  142079.000000  142079.000000  1.401820e+05
# mean   211625.235095      65.706121      70.726335  2.268820e+06
# std     34846.473490       7.064665       6.271695  5.779823e+06
# min         2.000000      40.000000      40.000000  1.000000e+03
# 25%    196142.000000      61.000000      66.000000  3.000000e+05
# 50%    216393.000000      66.000000      70.000000  7.000000e+05
# 75%    234430.000000      70.000000      75.000000  1.800000e+06
# max    264640.000000      94.000000      95.000000  1.940000e+08
#
#             wage_eur            age      height_cm      weight_kg  \
# count  140457.000000  142079.000000  142079.000000  142079.000000
# mean    11113.728045      25.117125     181.206470      75.247911
# std     22251.563020       4.659230       6.734544       6.997585
# min       500.000000      16.000000     154.000000      49.000000
# 25%      2000.000000      21.000000     176.000000      70.000000
# 50%      4000.000000      25.000000     181.000000      75.000000
# 75%     10000.000000      28.000000     186.000000      80.000000
# max    575000.000000      54.000000     208.000000     110.000000
#
#         club_team_id   league_level  ...  mentality_composure  \
# count  140449.000000  140064.000000  ...        110301.000000
# mean    44486.178762       1.378584  ...            57.787572
# std     53281.055198       0.748417  ...            12.375479
# min         1.000000       1.000000  ...             3.000000
# 25%       449.000000       1.000000  ...            50.000000
# 50%      1887.000000       1.000000  ...            59.000000
# 75%    110799.000000       2.000000  ...            66.000000
# max    115820.000000       5.000000  ...            96.000000
#
#        defending_marking_awareness  defending_standing_tackle  \
# count                142079.000000              142079.000000
# mean                     45.664278                  47.607402
# std                      20.456693                  21.352377
# min                       1.000000                   2.000000
# 25%                      25.000000                  26.000000
# 50%                      50.000000                  54.000000
# 75%                      63.000000                  66.000000
# max                      94.000000                  94.000000
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# count             142079.000000       142079.000000         142079.000000
# mean                  45.649913           16.542874             16.289346
# std                   20.963372           17.679880             16.829113
# min                    3.000000            1.000000              1.000000
# 25%                   25.000000            8.000000              8.000000
# 50%                   52.000000           11.000000             11.000000
# 75%                   64.000000           14.000000             14.000000
# max                   95.000000           91.000000             92.000000
#
#        goalkeeping_kicking  goalkeeping_positioning  goalkeeping_reflexes  \
# count        142079.000000            142079.000000         142079.000000
# mean             16.149185                16.297947             16.654221
# std              16.454171                16.991869             17.985856
# min               1.000000                 1.000000              1.000000
# 25%               8.000000                 8.000000              8.000000
# 50%              11.000000                11.000000             11.000000
# 75%              14.000000                14.000000             14.000000
# max              95.000000                92.000000             94.000000
#
#        goalkeeping_speed
# count       15791.000000
# mean           39.531505
# std            10.434840
# min            12.000000
# 25%            32.000000
# 50%            41.000000
# 75%            47.000000
# max            68.000000
#
# [8 rows x 60 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142079 entries, 0 to 142078
# Columns: 110 entries, sofifa_id to nation_flag_url
# dtypes: float64(17), int64(43), object(50)
# memory usage: 119.2+ MB

# %% [markdown]
# # Clean Data

# %%
### [body_type , player_tags , player_traits] type mmkn nd5lo

# %% [markdown]
# Drop uneccessary columns

# %%
df = df.drop(['player_face_url','club_logo_url','club_flag_url','nation_logo_url','nation_flag_url','sofifa_id', 'player_url', 'short_name', 
              'long_name','player_positions','dob','club_team_id','club_loaned_from' ,'nationality_id', 'nationality_id' , 'nation_team_id',
              'body_type' , 'real_face' ,'player_traits' ] , axis=1)

# %%
df.shape
# Out:
# (142079, 92)

# %% [markdown]
# Handle missing data

# %%
## we have to divide the number of columns to show the missing data because they are too uch to appear

# %%
## get list of all columns in data frame to divide them
df.columns
# Out:
# Index(['overall', 'potential', 'value_eur', 'wage_eur', 'age', 'height_cm',
#        'weight_kg', 'club_name', 'league_name', 'league_level',
#        'club_position', 'club_jersey_number', 'club_joined',
#        'club_contract_valid_until', 'nationality_name', 'nation_position',
#        'nation_jersey_number', 'preferred_foot', 'weak_foot', 'skill_moves',
#        'international_reputation', 'work_rate', 'release_clause_eur',
#        'player_tags', 'pace', 'shooting', 'passing', 'dribbling', 'defending',
#        'physic', 'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking_awareness',
#        'defending_standing_tackle', 'defending_sliding_tackle',
#        'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed',
#        'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram',
#        'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb',
#        'lcb', 'cb', 'rcb', 'rb', 'gk'],
#       dtype='object')

# %%
## first part of data 
df_prt1 = df[ [ 'overall', 'potential', 'value_eur', 'wage_eur', 'age', 'height_cm',
       'weight_kg', 'club_name', 'league_name', 'league_level',
       'club_position', 'club_jersey_number', 'club_joined',
       'club_contract_valid_until', 'nationality_name', 'nation_position',
       'nation_jersey_number', 'preferred_foot', 'weak_foot', 'skill_moves','international_reputation', 'work_rate', 'release_clause_eur',
       'player_tags', 'pace', 'shooting', 'passing']]

# %%
## get the number of the missing data (part1)
df_prt1.isnull().sum()
# Out:
# overall                           0
# potential                         0
# value_eur                      1897
# wage_eur                       1622
# age                               0
# height_cm                         0
# weight_kg                         0
# club_name                      1630
# league_name                    1630
# league_level                   2015
# club_position                  1630
# club_jersey_number             1630
# club_joined                    9935
# club_contract_valid_until      1630
# nationality_name                  0
# nation_position              133635
# nation_jersey_number         133635
# preferred_foot                    0
# weak_foot                         0
# skill_moves                       0
# international_reputation          0
# work_rate                         0
# release_clause_eur            55582
# player_tags                  130765
# pace                          15791
# shooting                      15791
# passing                       15791
# dtype: int64

# %%
## missin percentage part(1)
df_prt1.isnull().mean()*100
# Out:
# overall                       0.000000
# potential                     0.000000
# value_eur                     1.335173
# wage_eur                      1.141618
# age                           0.000000
# height_cm                     0.000000
# weight_kg                     0.000000
# club_name                     1.147249
# league_name                   1.147249
# league_level                  1.418225
# club_position                 1.147249
# club_jersey_number            1.147249
# club_joined                   6.992589
# club_contract_valid_until     1.147249
# nationality_name              0.000000
# nation_position              94.056828
# nation_jersey_number         94.056828
# preferred_foot                0.000000
# weak_foot                     0.000000
# skill_moves                   0.000000
# international_reputation      0.000000
# work_rate                     0.000000
# release_clause_eur           39.120489
# player_tags                  92.036825
# pace                         11.114239
# shooting                     11.114239
# passing                      11.114239
# dtype: float64

# %%
###  i found alot of missing data in following columns[value_eur,wage_eur,club_name,league_name ,league_level ,club_position,club_jersey_number
###    ,club_joined ,club_contract_valid_until,nation_position ,nation_jersey_number,,,] so i will decide how i will handle them {fill , drop }

# %%
df["value_eur"].describe()
# Out:
# count    1.401820e+05
# mean     2.268820e+06
# std      5.779823e+06
# min      1.000000e+03
# 25%      3.000000e+05
# 50%      7.000000e+05
# 75%      1.800000e+06
# max      1.940000e+08
# Name: value_eur, dtype: float64

# %%
df_prt1.drop(df_prt1[df_prt1["value_eur"].isnull()].index , axis= 0 , inplace= True)
# Out:
# C:\Users\HP.SXS04\AppData\Local\Temp\ipykernel_15580\1646096794.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## we cant fill the missing the data so we will drop the null rows /  Note :there is a big difference between median and mean (squide data)
df.drop(df[df["value_eur"].isnull()].index , axis = 0 ,inplace =True  )

# %%
df_prt1.drop(df_prt1[df_prt1["value_eur"].isnull()].index , axis = 0  )
# Out:
#         overall  potential    value_eur  wage_eur  age  height_cm  weight_kg  \
# 0            93         95  100500000.0  550000.0   27        169         67
# 1            92         92   79000000.0  375000.0   29        185         80
# 2            90         90   54500000.0  275000.0   30        180         80
# 3            90         90   52500000.0  275000.0   32        195         95
# 4            90         90   63500000.0  300000.0   28        193         92
# ...         ...        ...          ...       ...  ...        ...        ...
# 142074       47         52      70000.0    1000.0   22        180         64
# 142075       47         59     110000.0     500.0   19        175         70
# 142076       47         55     100000.0     500.0   21        178         72
# 142077       47         60     110000.0     500.0   19        173         66
# 142078       47         60     110000.0     500.0   19        167         61
#
#                   club_name                     league_name  league_level  \
# 0              FC Barcelona          Spain Primera Division           1.0
# 1            Real Madrid CF          Spain Primera Division           1.0
# 2         FC Bayern München            German 1. Bundesliga           1.0
# 3       Paris Saint-Germain                  French Ligue 1           1.0
# 4         FC Bayern München            German 1. Bundesliga           1.0
# ...                     ...                             ...           ...
# 142074             Wuhan FC            Chinese Super League           1.0
# 142075           Derry City  Rep. Ireland Airtricity League           1.0
# 142076           Finn Harps  Rep. Ireland Airtricity League           1.0
# 142077           Finn Harps  Rep. Ireland Airtricity League           1.0
# 142078  NorthEast United FC             Indian Super League           1.0
#
#         ... preferred_foot  weak_foot skill_moves  international_reputation  \
# 0       ...           Left          3           4                         5
# 1       ...          Right          4           5                         5
# 2       ...           Left          2           4                         5
# 3       ...          Right          4           4                         5
# 4       ...          Right          4           1                         5
# ...     ...            ...        ...         ...                       ...
# 142074  ...          Right          3           2                         1
# 142075  ...          Right          3           2                         1
# 142076  ...          Right          3           2                         1
# 142077  ...          Right          3           2                         1
# 142078  ...          Right          3           2                         1
#
#             work_rate release_clause_eur  \
# 0          Medium/Low                NaN
# 1            High/Low                NaN
# 2            High/Low                NaN
# 3          Medium/Low                NaN
# 4       Medium/Medium                NaN
# ...               ...                ...
# 142074  Medium/Medium           114000.0
# 142075  Medium/Medium           193000.0
# 142076  Medium/Medium           175000.0
# 142077  Medium/Medium           239000.0
# 142078  Medium/Medium           217000.0
#
#                                               player_tags  pace  shooting  \
# 0       #Speedster, #Dribbler, #FK Specialist, #Acroba...  93.0      89.0
# 1       #Speedster, #Dribbler, #Distance Shooter, #Acr...  93.0      93.0
# 2       #Speedster, #Dribbler, #Distance Shooter, #Acr...  93.0      86.0
# 3       #Poacher, #Aerial Threat, #Distance Shooter, #...  76.0      91.0
# 4                                                     NaN   NaN       NaN
# ...                                                   ...   ...       ...
# 142074                                                NaN  58.0      35.0
# 142075                                                NaN  59.0      39.0
# 142076                                                NaN  60.0      37.0
# 142077                                                NaN  68.0      46.0
# 142078                                                NaN  68.0      38.0
#
#         passing
# 0          86.0
# 1          81.0
# 2          83.0
# 3          81.0
# 4           NaN
# ...         ...
# 142074     46.0
# 142075     50.0
# 142076     45.0
# 142077     36.0
# 142078     45.0
#
# [140182 rows x 27 columns]

# %%
df_prt1.isnull().sum()
# Out:
# overall                           0
# potential                         0
# value_eur                         0
# wage_eur                          0
# age                               0
# height_cm                         0
# weight_kg                         0
# club_name                         8
# league_name                       8
# league_level                    393
# club_position                     8
# club_jersey_number                8
# club_joined                    8308
# club_contract_valid_until         8
# nationality_name                  0
# nation_position              133366
# nation_jersey_number         133366
# preferred_foot                    0
# weak_foot                         0
# skill_moves                       0
# international_reputation          0
# work_rate                         0
# release_clause_eur            53685
# player_tags                  129010
# pace                          15543
# shooting                      15543
# passing                       15543
# dtype: int64

# %%
## handle missing in player_tags 
df.player_tags.value_counts()
# Out:
# #Strength                                                                                                                          3728
# #Acrobat                                                                                                                           1802
# #Engine                                                                                                                            1454
# #Speedster                                                                                                                         1240
# #Speedster, #Acrobat                                                                                                                516
#                                                                                                                                    ...
# #Dribbler, #Engine, #Acrobat, #Clinical Finisher, #Complete Forward                                                                   1
# #Engine, #Distance Shooter, #Strength                                                                                                 1
# #Dribbler, #Playmaker, #Distance Shooter, #FK Specialist, #Acrobat, #Clinical Finisher, #Complete Midfielder, #Complete Forward       1
# #Poacher, #Speedster, #Complete Forward                                                                                               1
# #Engine, #Strength, #Clinical Finisher, #Complete Forward                                                                             1
# Name: player_tags, Length: 162, dtype: int64

# %%
## i cant fill the misiing columns so i have to drop the column
df.drop("player_tags" , axis = 1 , inplace = True)

# %%
## i cant fill the misiing columns so i have to drop the column
df_prt1.drop("player_tags" , axis = 1 , inplace = True)
# Out:
# C:\Users\HP.SXS04\AppData\Local\Temp\ipykernel_15580\3170349582.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_prt1.isnull().sum()
# Out:
# overall                           0
# potential                         0
# value_eur                         0
# wage_eur                          0
# age                               0
# height_cm                         0
# weight_kg                         0
# club_name                         8
# league_name                       8
# league_level                    393
# club_position                     8
# club_jersey_number                8
# club_joined                    8308
# club_contract_valid_until         8
# nationality_name                  0
# nation_position              133366
# nation_jersey_number         133366
# preferred_foot                    0
# weak_foot                         0
# skill_moves                       0
# international_reputation          0
# work_rate                         0
# release_clause_eur            53685
# pace                          15543
# shooting                      15543
# passing                       15543
# dtype: int64

# %%
## we cant fill the columns so we will drop 
df.drop(['nation_jersey_number', "nation_position"] , axis = 1 , inplace=True)

# %%
df_prt1.drop(['nation_jersey_number', "nation_position"] , axis = 1 , inplace=True)
# Out:
# C:\Users\HP.SXS04\AppData\Local\Temp\ipykernel_15580\2869306295.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_prt1.isnull().sum()
# Out:
# overall                          0
# potential                        0
# value_eur                        0
# wage_eur                         0
# age                              0
# height_cm                        0
# weight_kg                        0
# club_name                        8
# league_name                      8
# league_level                   393
# club_position                    8
# club_jersey_number               8
# club_joined                   8308
# club_contract_valid_until        8
# nationality_name                 0
# preferred_foot                   0
# weak_foot                        0
# skill_moves                      0
# international_reputation         0
# work_rate                        0
# release_clause_eur           53685
# pace                         15543
# shooting                     15543
# passing                      15543
# dtype: int64

# %% [markdown]
# ##############################################################################################################################################################################################

# %%
## handle release_clause_eur
df.release_clause_eur.describe()
# Out:
# count    8.649700e+04
# mean     4.683635e+06
# std      1.169333e+07
# min      9.000000e+03
# 25%      5.780000e+05
# 50%      1.300000e+06
# 75%      3.500000e+06
# max      3.735000e+08
# Name: release_clause_eur, dtype: float64

# %%
df.release_clause_eur.mean()
# Out:
# 4683635.074048811

# %%
## i can fill the release clauss with mean values

# df.release_clause_eur.fillna(df.release_clause_eur.mean() , inplace= True)

# %%
df_prt1.release_clause_eur.fillna(df.release_clause_eur.mean() , inplace= True)
# Out:
# C:\Users\HP.SXS04\AppData\Local\Temp\ipykernel_15580\1883859345.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_prt1.isnull().sum()
# Out:
# overall                          0
# potential                        0
# value_eur                        0
# wage_eur                         0
# age                              0
# height_cm                        0
# weight_kg                        0
# club_name                        8
# league_name                      8
# league_level                   393
# club_position                    8
# club_jersey_number               8
# club_joined                   8308
# club_contract_valid_until        8
# nationality_name                 0
# preferred_foot                   0
# weak_foot                        0
# skill_moves                      0
# international_reputation         0
# work_rate                        0
# release_clause_eur               0
# pace                         15543
# shooting                     15543
# passing                      15543
# dtype: int64

# %% [markdown]
# ##############################################################################################################################################################################################

# %%
df_prt1.isnull().sum()
# Out:
# overall                          0
# potential                        0
# value_eur                        0
# wage_eur                         0
# age                              0
# height_cm                        0
# weight_kg                        0
# club_name                        8
# league_name                      8
# league_level                   393
# club_position                    8
# club_jersey_number               8
# club_joined                   8308
# club_contract_valid_until        8
# nationality_name                 0
# preferred_foot                   0
# weak_foot                        0
# skill_moves                      0
# international_reputation         0
# work_rate                        0
# release_clause_eur               0
# pace                         15543
# shooting                     15543
# passing                      15543
# dtype: int64

# %% [markdown]
# #################################################################################################################################################################################################

# %%
## haandle pace , shooting ,passing
df.shooting.describe()
# Out:
# count    124639.000000
# mean         52.185720
# std          13.928307
# min          14.000000
# 25%          42.000000
# 50%          54.000000
# 75%          63.000000
# max          94.000000
# Name: shooting, dtype: float64

# %%
df.pace.describe()
# Out:
# count    124639.000000
# mean         68.030295
# std          11.078422
# min          21.000000
# 25%          62.000000
# 50%          69.000000
# 75%          76.000000
# max          97.000000
# Name: pace, dtype: float64

# %%
df.passing.describe()
# Out:
# count    124639.000000
# mean         56.869656
# std          10.551151
# min          20.000000
# 25%          50.000000
# 50%          58.000000
# 75%          64.000000
# max          93.000000
# Name: passing, dtype: float64

# %%
# df.pace.fillna(df.pace.mean() , inplace= True)

# %%
# df.shooting.fillna(df.shooting.mean() , inplace= True)

# %%
# df.passing.fillna(df.passing.mean() , inplace= True)

# %%
df_prt1.pace.fillna(df.pace.mean() , inplace= True)
# Out:
# C:\Users\HP.SXS04\AppData\Local\Temp\ipykernel_15580\3856165304.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_prt1.shooting.fillna(df.shooting.mean() , inplace= True)
# Out:
# C:\Users\HP.SXS04\AppData\Local\Temp\ipykernel_15580\2737111343.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_prt1 .passing.fillna(df.passing.mean() , inplace= True)
# Out:
# C:\Users\HP.SXS04\AppData\Local\Temp\ipykernel_15580\2598670331.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_prt1.isnull().sum()
# Out:
# overall                         0
# potential                       0
# value_eur                       0
# wage_eur                        0
# age                             0
# height_cm                       0
# weight_kg                       0
# club_name                       8
# league_name                     8
# league_level                  393
# club_position                   8
# club_jersey_number              8
# club_joined                  8308
# club_contract_valid_until       8
# nationality_name                0
# preferred_foot                  0
# weak_foot                       0
# skill_moves                     0
# international_reputation        0
# work_rate                       0
# release_clause_eur              0
# pace                            0
# shooting                        0
# passing                         0
# dtype: int64

# %% [markdown]
# ################################################################################################################################################################################################

# %%
## handle clube joined
df.club_joined.describe()
# Out:
# count         131874
# unique          3705
# top       2017-07-01
# freq            4124
# Name: club_joined, dtype: object

# %%
df[df['club_joined'].isnull()]
# Out:
#         overall  potential   value_eur  wage_eur  age  height_cm  weight_kg  \
# 10           88         88  46500000.0  250000.0   28        177         72
# 72           83         83  17000000.0  140000.0   28        186         79
# 159          81         81  10500000.0  110000.0   30        186         78
# 165          81         82  12000000.0  110000.0   27        175         66
# 187          81         83  14000000.0  130000.0   26        175         71
# ...         ...        ...         ...       ...  ...        ...        ...
# 141765       51         65    140000.0    4000.0   21        168         66
# 141769       51         59    120000.0    2000.0   21        192         77
# 141771       51         64    140000.0     500.0   20        174         70
# 141881       50         61    110000.0     500.0   22        175         59
# 142027       48         53     70000.0    3000.0   20        172         65
#
#                         club_name                   league_name  league_level  \
# 10              Manchester United        English Premier League           1.0
# 72                    Valencia CF        Spain Primera Division           1.0
# 159                      AC Milan               Italian Serie A           1.0
# 165                   Sporting CP    Portuguese Liga ZON SAGRES           1.0
# 187                Real Madrid CF        Spain Primera Division           1.0
# ...                           ...                           ...           ...
# 141765                    Al Raed  Saudi Abdul L. Jameel League           1.0
# 141769                   Wuhan FC          Chinese Super League           1.0
# 141771          SC East Bengal FC           Indian Super League           1.0
# 141881          SC East Bengal FC           Indian Super League           1.0
# 142027  Henan Songshan Longmen FC          Chinese Super League           1.0
#
#         ...   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb    gk
# 10      ...  60+2  60+2  60+2  58+2  56+2  55+2  55+2  55+2  56+2  14+2
# 72      ...  62+1  62+1  62+1  57+1  55+1  57+1  57+1  57+1  55+1  14+1
# 159     ...  58+1  58+1  58+1  57+1  53+1  49+1  49+1  49+1  53+1  16+1
# 165     ...    59    59    59    58    50    42    42    42    50    11
# 187     ...  53+1  53+1  53+1  54+1  51+1  46+1  46+1  46+1  51+1  16+1
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 141765  ...  48+2  48+2  48+2  47+2  46+2  46+2  46+2  46+2  46+2  17+2
# 141769  ...  43+2  43+2  43+2  44+2  47+2  51+2  51+2  51+2  47+2  13+2
# 141771  ...  35+2  35+2  35+2  41+2  39+2  34+2  34+2  34+2  39+2  15+2
# 141881  ...  30+2  30+2  30+2  34+2  33+2  27+2  27+2  27+2  33+2  12+2
# 142027  ...  30+2  30+2  30+2  33+2  32+2  29+2  29+2  29+2  32+2  15+2
#
# [8308 rows x 89 columns]

# %%
df.drop(df[df['club_joined'].isnull()].index , axis = 0 , inplace =True)

# %%
df_prt1.drop(df_prt1[df_prt1['club_joined'].isnull()].index , axis = 0 , inplace =True)
# Out:
# C:\Users\HP.SXS04\AppData\Local\Temp\ipykernel_15580\2199519623.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_prt1.isnull().sum()
# Out:
# overall                        0
# potential                      0
# value_eur                      0
# wage_eur                       0
# age                            0
# height_cm                      0
# weight_kg                      0
# club_name                      0
# league_name                    0
# league_level                 385
# club_position                  0
# club_jersey_number             0
# club_joined                    0
# club_contract_valid_until      0
# nationality_name               0
# preferred_foot                 0
# weak_foot                      0
# skill_moves                    0
# international_reputation       0
# work_rate                      0
# release_clause_eur             0
# pace                           0
# shooting                       0
# passing                        0
# dtype: int64

# %%
df.drop(df[df['league_level'].isnull()].index , axis = 0 , inplace = True )

# %%
df_prt1.drop(df_prt1[df_prt1['league_level'].isnull()].index , axis = 0 , inplace = True )
# Out:
# C:\Users\HP.SXS04\AppData\Local\Temp\ipykernel_15580\1496962860.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## part2 of data 
df_prt2 = df[['dribbling', 'defending',
       'physic', 'attacking_crossing', 'attacking_finishing',
       'attacking_heading_accuracy', 'attacking_short_passing',
       'attacking_volleys', 'skill_dribbling', 'skill_curve',
       'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
       'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
       'movement_reactions', 'movement_balance', 'power_shot_power','power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
       'mentality_aggression', 'mentality_interceptions','mentality_positioning', 'mentality_vision', 'mentality_penalties']]

# %%
## get the number of the missing data part(2)
df_prt2.isnull().sum()
# Out:
# dribbling                     14864
# defending                     14864
# physic                        14864
# attacking_crossing                0
# attacking_finishing               0
# attacking_heading_accuracy        0
# attacking_short_passing           0
# attacking_volleys                 0
# skill_dribbling                   0
# skill_curve                       0
# skill_fk_accuracy                 0
# skill_long_passing                0
# skill_ball_control                0
# movement_acceleration             0
# movement_sprint_speed             0
# movement_agility                  0
# movement_reactions                0
# movement_balance                  0
# power_shot_power                  0
# power_jumping                     0
# power_stamina                     0
# power_strength                    0
# power_long_shots                  0
# mentality_aggression              0
# mentality_interceptions           0
# mentality_positioning             0
# mentality_vision                  0
# mentality_penalties               0
# dtype: int64

# %%
### missin percentage 
df_prt2.isnull().mean()*100
# Out:
# dribbling                     11.304368
# defending                     11.304368
# physic                        11.304368
# attacking_crossing             0.000000
# attacking_finishing            0.000000
# attacking_heading_accuracy     0.000000
# attacking_short_passing        0.000000
# attacking_volleys              0.000000
# skill_dribbling                0.000000
# skill_curve                    0.000000
# skill_fk_accuracy              0.000000
# skill_long_passing             0.000000
# skill_ball_control             0.000000
# movement_acceleration          0.000000
# movement_sprint_speed          0.000000
# movement_agility               0.000000
# movement_reactions             0.000000
# movement_balance               0.000000
# power_shot_power               0.000000
# power_jumping                  0.000000
# power_stamina                  0.000000
# power_strength                 0.000000
# power_long_shots               0.000000
# mentality_aggression           0.000000
# mentality_interceptions        0.000000
# mentality_positioning          0.000000
# mentality_vision               0.000000
# mentality_penalties            0.000000
# dtype: float64

# %%
## HANDLE DRIPLING , DEFENDING , PHYSIC
df.dribbling.describe()
# Out:
# count    116625.000000
# mean         61.894036
# std          10.415119
# min          22.000000
# 25%          56.000000
# 50%          63.000000
# 75%          69.000000
# max          96.000000
# Name: dribbling, dtype: float64

# %%
df.defending.describe()
# Out:
# count    116625.000000
# mean         51.158268
# std          16.633085
# min          14.000000
# 25%          36.000000
# 50%          56.000000
# 75%          64.000000
# max          91.000000
# Name: defending, dtype: float64

# %%
df.physic.describe()
# Out:
# count    116625.000000
# mean         64.860896
# std           9.760671
# min          27.000000
# 25%          59.000000
# 50%          66.000000
# 75%          72.000000
# max          92.000000
# Name: physic, dtype: float64

# %%
#df.dribbling.fillna(df.dribbling.mean() , axis = 0 , inplace =True)

# %%
df_prt2.dribbling.fillna(df_prt2.dribbling.mean() , axis = 0 , inplace =True)
# Out:
# C:\Users\HP.SXS04\AppData\Local\Temp\ipykernel_15580\1304634353.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# df.defending.fillna(df.defending.mean() , axis = 0 , inplace =True)

# %%
df_prt2.defending.fillna(df_prt2.defending.mean() , axis = 0 , inplace =True)
# Out:
# C:\Users\HP.SXS04\AppData\Local\Temp\ipykernel_15580\111250320.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#  df.physic.fillna(df.physic.mean() , axis = 0 , inplace =True)

# %%
df_prt2.physic.fillna(df_prt2.physic.mean() , axis = 0 , inplace =True)
# Out:
# C:\Users\HP.SXS04\AppData\Local\Temp\ipykernel_15580\2385400230.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_prt2.isnull().sum()
# Out:
# dribbling                     0
# defending                     0
# physic                        0
# attacking_crossing            0
# attacking_finishing           0
# attacking_heading_accuracy    0
# attacking_short_passing       0
# attacking_volleys             0
# skill_dribbling               0
# skill_curve                   0
# skill_fk_accuracy             0
# skill_long_passing            0
# skill_ball_control            0
# movement_acceleration         0
# movement_sprint_speed         0
# movement_agility              0
# movement_reactions            0
# movement_balance              0
# power_shot_power              0
# power_jumping                 0
# power_stamina                 0
# power_strength                0
# power_long_shots              0
# mentality_aggression          0
# mentality_interceptions       0
# mentality_positioning         0
# mentality_vision              0
# mentality_penalties           0
# dtype: int64

# %%
## data part(3)
df_prt3 = df[['mentality_composure', 'defending_marking_awareness',
       'defending_standing_tackle', 'defending_sliding_tackle',
       'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
       'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed',
       'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram','lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm']]

# %%
df_prt3.isnull().sum()
# Out:
# mentality_composure             29260
# defending_marking_awareness         0
# defending_standing_tackle           0
# defending_sliding_tackle            0
# goalkeeping_diving                  0
# goalkeeping_handling                0
# goalkeeping_kicking                 0
# goalkeeping_positioning             0
# goalkeeping_reflexes                0
# goalkeeping_speed              116625
# ls                                  0
# st                                  0
# rs                                  0
# lw                                  0
# lf                                  0
# cf                                  0
# rf                                  0
# rw                                  0
# lam                                 0
# cam                                 0
# ram                                 0
# lm                                  0
# lcm                                 0
# cm                                  0
# rcm                                 0
# rm                                  0
# lwb                                 0
# ldm                                 0
# dtype: int64

# %%
df_prt3.isnull().mean()*100
# Out:
# mentality_composure            22.252812
# defending_marking_awareness     0.000000
# defending_standing_tackle       0.000000
# defending_sliding_tackle        0.000000
# goalkeeping_diving              0.000000
# goalkeeping_handling            0.000000
# goalkeeping_kicking             0.000000
# goalkeeping_positioning         0.000000
# goalkeeping_reflexes            0.000000
# goalkeeping_speed              88.695632
# ls                              0.000000
# st                              0.000000
# rs                              0.000000
# lw                              0.000000
# lf                              0.000000
# cf                              0.000000
# rf                              0.000000
# rw                              0.000000
# lam                             0.000000
# cam                             0.000000
# ram                             0.000000
# lm                              0.000000
# lcm                             0.000000
# cm                              0.000000
# rcm                             0.000000
# rm                              0.000000
# lwb                             0.000000
# ldm                             0.000000
# dtype: float64

# %%
df.mentality_composure.describe()
# Out:
# count    102229.000000
# mean         57.688934
# std          12.453684
# min           3.000000
# 25%          50.000000
# 50%          59.000000
# 75%          66.000000
# max          96.000000
# Name: mentality_composure, dtype: float64

# %%
# df.mentality_composure.fillna(df.mentality_composure.mean() , axis = 0 , inplace =True)

# %%
df_prt3.mentality_composure.fillna(df_prt3.mentality_composure.mean() , axis = 0 , inplace =True)
# Out:
# C:\Users\HP.SXS04\AppData\Local\Temp\ipykernel_15580\3325233523.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
 # df.goalkeeping_speed .fillna(df.goalkeeping_speed .mean() , axis = 0 , inplace =True)

# %%
df_prt3.goalkeeping_speed .fillna(df_prt3.goalkeeping_speed .mean() , axis = 0 , inplace =True)
# Out:
# C:\Users\HP.SXS04\AppData\Local\Temp\ipykernel_15580\3597964151.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_prt3.isnull().sum()
# Out:
# mentality_composure            0
# defending_marking_awareness    0
# defending_standing_tackle      0
# defending_sliding_tackle       0
# goalkeeping_diving             0
# goalkeeping_handling           0
# goalkeeping_kicking            0
# goalkeeping_positioning        0
# goalkeeping_reflexes           0
# goalkeeping_speed              0
# ls                             0
# st                             0
# rs                             0
# lw                             0
# lf                             0
# cf                             0
# rf                             0
# rw                             0
# lam                            0
# cam                            0
# ram                            0
# lm                             0
# lcm                            0
# cm                             0
# rcm                            0
# rm                             0
# lwb                            0
# ldm                            0
# dtype: int64

# %%
df_prt4 = df[['cdm', 'rdm', 'rwb', 'lb',
       'lcb', 'cb', 'rcb', 'rb', 'gk']]

# %%
df_prt4.isnull().sum()
# Out:
# cdm    0
# rdm    0
# rwb    0
# lb     0
# lcb    0
# cb     0
# rcb    0
# rb     0
# gk     0
# dtype: int64

# %%
## now after i handled all the missing data we will start to explore data and start feautre engineering process

# %% [markdown]
# ## feature engineering

# %%
df.columns
# Out:
# Index(['overall', 'potential', 'value_eur', 'wage_eur', 'age', 'height_cm',
#        'weight_kg', 'club_name', 'league_name', 'league_level',
#        'club_position', 'club_jersey_number', 'club_joined',
#        'club_contract_valid_until', 'nationality_name', 'preferred_foot',
#        'weak_foot', 'skill_moves', 'international_reputation', 'work_rate',
#        'release_clause_eur', 'pace', 'shooting', 'passing', 'dribbling',
#        'defending', 'physic', 'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking_awareness',
#        'defending_standing_tackle', 'defending_sliding_tackle',
#        'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed',
#        'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram',
#        'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb',
#        'lcb', 'cb', 'rcb', 'rb', 'gk'],
#       dtype='object')

# %%
## i can extract new feature (loyality ) as it indicate how many year did player stay in club and if it will make a difference in the value or not 
df.club_joined = df.club_joined.astype('datetime64[ns]')

# %%
df.club_joined = df.club_joined.dt.year

# %%
df['loyality'] = df.club_contract_valid_until - df.club_joined

# %%
df.drop(["club_contract_valid_until" ,"club_joined" ]  , axis = 1 , inplace = True  )

# %%
df.loyality.describe()
# Out:
# count    131489.000000
# mean          4.016229
# std           2.512183
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           5.000000
# max          30.000000
# Name: loyality, dtype: float64

# %%
df.work_rate.value_counts()
# Out:
# Medium/Medium    73024
# High/Medium      22128
# Medium/High      11857
# High/High         6312
# Medium/Low        6298
# High/Low          5146
# Low/Medium        3290
# Low/High          3165
# Low/Low            269
# Name: work_rate, dtype: int64

# %%
#handle last 10 columns as they nedd to remove + from numbers
df.select_dtypes('O').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131489 entries, 0 to 142078
# Data columns (total 33 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   club_name         131489 non-null  object
#  1   league_name       131489 non-null  object
#  2   club_position     131489 non-null  object
#  3   nationality_name  131489 non-null  object
#  4   preferred_foot    131489 non-null  object
#  5   work_rate         131489 non-null  object
#  6   ls                131489 non-null  object
#  7   st                131489 non-null  object
#  8   rs                131489 non-null  object
#  9   lw                131489 non-null  object
#  10  lf                131489 non-null  object
#  11  cf                131489 non-null  object
#  12  rf                131489 non-null  object
#  13  rw                131489 non-null  object
#  14  lam               131489 non-null  object
#  15  cam               131489 non-null  object
#  16  ram               131489 non-null  object
#  17  lm                131489 non-null  object
#  18  lcm               131489 non-null  object
#  19  cm                131489 non-null  object
#  20  rcm               131489 non-null  object
#  21  rm                131489 non-null  object
#  22  lwb               131489 non-null  object
#  23  ldm               131489 non-null  object
#  24  cdm               131489 non-null  object
#  25  rdm               131489 non-null  object
#  26  rwb               131489 non-null  object
#  27  lb                131489 non-null  object
#  28  lcb               131489 non-null  object
#  29  cb                131489 non-null  object
#  30  rcb               131489 non-null  object
#  31  rb                131489 non-null  object
#  32  gk                131489 non-null  object
# dtypes: object(33)
# memory usage: 34.1+ MB

# %%
df_prt1
# Out:
#         overall  potential    value_eur  wage_eur  age  height_cm  weight_kg  \
# 0            93         95  100500000.0  550000.0   27        169         67
# 1            92         92   79000000.0  375000.0   29        185         80
# 2            90         90   54500000.0  275000.0   30        180         80
# 3            90         90   52500000.0  275000.0   32        195         95
# 4            90         90   63500000.0  300000.0   28        193         92
# ...         ...        ...          ...       ...  ...        ...        ...
# 142074       47         52      70000.0    1000.0   22        180         64
# 142075       47         59     110000.0     500.0   19        175         70
# 142076       47         55     100000.0     500.0   21        178         72
# 142077       47         60     110000.0     500.0   19        173         66
# 142078       47         60     110000.0     500.0   19        167         61
#
#                   club_name                     league_name  league_level  \
# 0              FC Barcelona          Spain Primera Division           1.0
# 1            Real Madrid CF          Spain Primera Division           1.0
# 2         FC Bayern München            German 1. Bundesliga           1.0
# 3       Paris Saint-Germain                  French Ligue 1           1.0
# 4         FC Bayern München            German 1. Bundesliga           1.0
# ...                     ...                             ...           ...
# 142074             Wuhan FC            Chinese Super League           1.0
# 142075           Derry City  Rep. Ireland Airtricity League           1.0
# 142076           Finn Harps  Rep. Ireland Airtricity League           1.0
# 142077           Finn Harps  Rep. Ireland Airtricity League           1.0
# 142078  NorthEast United FC             Indian Super League           1.0
#
#         ...     nationality_name  preferred_foot weak_foot  skill_moves  \
# 0       ...            Argentina            Left         3            4
# 1       ...             Portugal           Right         4            5
# 2       ...          Netherlands            Left         2            4
# 3       ...               Sweden           Right         4            4
# 4       ...              Germany           Right         4            1
# ...     ...                  ...             ...       ...          ...
# 142074  ...             China PR           Right         3            2
# 142075  ...  Republic of Ireland           Right         3            2
# 142076  ...  Republic of Ireland           Right         3            2
# 142077  ...  Republic of Ireland           Right         3            2
# 142078  ...                India           Right         3            2
#
#        international_reputation      work_rate  release_clause_eur       pace  \
# 0                             5     Medium/Low        4.683635e+06  93.000000
# 1                             5       High/Low        4.683635e+06  93.000000
# 2                             5       High/Low        4.683635e+06  93.000000
# 3                             5     Medium/Low        4.683635e+06  76.000000
# 4                             5  Medium/Medium        4.683635e+06  68.030295
# ...                         ...            ...                 ...        ...
# 142074                        1  Medium/Medium        1.140000e+05  58.000000
# 142075                        1  Medium/Medium        1.930000e+05  59.000000
# 142076                        1  Medium/Medium        1.750000e+05  60.000000
# 142077                        1  Medium/Medium        2.390000e+05  68.000000
# 142078                        1  Medium/Medium        2.170000e+05  68.000000
#
#         shooting    passing
# 0       89.00000  86.000000
# 1       93.00000  81.000000
# 2       86.00000  83.000000
# 3       91.00000  81.000000
# 4       52.18572  56.869656
# ...          ...        ...
# 142074  35.00000  46.000000
# 142075  39.00000  50.000000
# 142076  37.00000  45.000000
# 142077  46.00000  36.000000
# 142078  38.00000  45.000000
#
# [131489 rows x 24 columns]

# %% [markdown]
# # split data

# %%
"""df.drop(['ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram',
       'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb',
       'lcb', 'cb', 'rcb', 'rb', 'gk' , 'league_name', 'nationality_name' ,'release_clause_eur' ,'work_rate'] , axis = 1 , inplace=True)
       """
# Out:
# "df.drop(['ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram',\n       'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb',\n       'lcb', 'cb', 'rcb', 'rb', 'gk' , 'league_name', 'nationality_name' ,'release_clause_eur' ,'work_rate'] , axis = 1 , inplace=True)\n       "

# %%
df.shape
# Out:
# (131489, 88)

# %%
x= df.drop('value_eur' , axis = 1 )

# %%
y = df['value_eur']

# %%
 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (105191, 87)

# %%
x_train.isnull().sum()[50:57]
# Out:
# defending_marking_awareness    0
# defending_standing_tackle      0
# defending_sliding_tackle       0
# goalkeeping_diving             0
# goalkeeping_handling           0
# goalkeeping_kicking            0
# goalkeeping_positioning        0
# dtype: int64

# %%
x_train.isnull().sum()[19:27]
# Out:
# shooting                      11906
# passing                       11906
# dribbling                     11906
# defending                     11906
# physic                        11906
# attacking_crossing                0
# attacking_finishing               0
# attacking_heading_accuracy        0
# dtype: int64

# %%
x_train.pace.fillna(x_train.pace.mean() , inplace= True)
x_train.shooting.fillna(x_train.shooting.mean() , inplace= True)
x_train.passing.fillna(x_train.passing.mean() , inplace= True)
x_train.dribbling.fillna(x_train.dribbling.mean() , axis = 0 , inplace =True)
x_train.defending.fillna(x_train.defending.mean() , axis = 0 , inplace =True)
x_train.physic.fillna(x_train.physic.mean() , axis = 0 , inplace =True)
x_train.mentality_composure.fillna(x_train.mentality_composure.mean() , axis = 0 , inplace =True)
x_train.goalkeeping_speed .fillna(x_train.goalkeeping_speed .mean() , axis = 0 , inplace =True)
x_train.release_clause_eur.fillna(x_train.release_clause_eur.mean() , inplace= True)

# %%
x_test.pace.fillna(x_train.pace.mean() , inplace= True)
x_test.shooting.fillna(x_train.shooting.mean() , inplace= True)
x_test.passing.fillna(x_train.passing.mean() , inplace= True)
x_test.dribbling.fillna(x_train.dribbling.mean() , axis = 0 , inplace =True)
x_test.defending.fillna(x_train.defending.mean() , axis = 0 , inplace =True)
x_test.physic.fillna(x_train.physic.mean() , axis = 0 , inplace =True)
x_test.mentality_composure.fillna(x_train.mentality_composure.mean() , axis = 0 , inplace =True)
x_test.goalkeeping_speed .fillna(x_train.goalkeeping_speed .mean() , axis = 0 , inplace =True)
x_test.release_clause_eur.fillna(x_train.release_clause_eur.mean() , inplace= True)

# %%
l = ['ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram',
       'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb',
       'lcb', 'cb', 'rcb', 'rb', 'gk']

# %%
for i in l :
    x_train[i] = x_train[i].str.split("+").str[0]

# %%
for i in l :
   x_train[i] = x_train[i].str.split("-").str[0]

# %%
for i in l :
   x_test[i] = x_test[i].str.split("+").str[0]

# %%
for i in l :
    x_test[i] = x_test[i].str.split("-").str[0]

# %%
# this function constructed to show if any columns have a nan value after spliting the data 

for i in l :
    if x_train[i].isnull().sum() == 0 :
        pass
    else :
        print( i  , "has nan value")
# Out:
# lw has nan value
# lf has nan value
# cf has nan value
# rf has nan value
# rw has nan value
# gk has nan value

# %%
##   i will fill the missing value in [lw,lf,cf,cf .... ] with mean but i dont have the mean because Not all values are int so i cant use df.lw.mean() so i replaced the NAN values with 0 
## then i will calculate the mean of all wanted columns then i fill the nan values with 
##df.lw.mean() == 54
##df.lf.mean() == 54
##df.cf.mean() == 54
##df.rf.mean() == 54
##df.rw.mean() == 54
##df.gk.mean() == 19

# %%
x_train.lw.fillna('54', axis = 0 , inplace = True)
x_train.lf.fillna('54', axis = 0 , inplace = True)
x_train.cf.fillna('54', axis = 0 , inplace = True)
x_train.rf.fillna('54', axis = 0 , inplace = True)
x_train.rw.fillna('54', axis = 0 , inplace = True)
x_train.gk.fillna('19', axis = 0 , inplace = True)

# %%
x_test.lw.fillna('54', axis = 0 , inplace = True)
x_test.lf.fillna('54', axis = 0 , inplace = True)
x_test.cf.fillna('54', axis = 0 , inplace = True)
x_test.rf.fillna('54', axis = 0 , inplace = True)
x_test.rw.fillna('54', axis = 0 , inplace = True)
x_test.gk.fillna('19', axis = 0 , inplace = True)

# %%
for i in l :
   x_train[i]= x_train[i].astype(int)

# %%
for i in l :
   x_test[i]= x_test[i].astype(int)

# %%
x_train.select_dtypes("O").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105191 entries, 79296 to 132030
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   club_name         105191 non-null  object
#  1   league_name       105191 non-null  object
#  2   club_position     105191 non-null  object
#  3   nationality_name  105191 non-null  object
#  4   preferred_foot    105191 non-null  object
#  5   work_rate         105191 non-null  object
# dtypes: object(6)
# memory usage: 5.6+ MB

# %%
x_train.drop('club_name' , axis = 1 , inplace= True)

# %%
x_test.drop('club_name' , axis = 1 , inplace= True)

# %%
"""x_test2.drop('club_name' , axis = 1 , inplace= True)
"""
# Out:
# "x_test2.drop('club_name' , axis = 1 , inplace= True)\n"

# %% [markdown]
# # Handle categorical data

# %%
encoder = BinaryEncoder(cols=[  'league_name', 'nationality_name' ,'release_clause_eur' ,'work_rate' ,'club_position'  , 'preferred_foot'])

# %%
x_train=encoder.fit_transform(x_train)

# %%
x_test=encoder.transform(x_test)

# %% [markdown]
# ## Scaling data

# %%
scaler = MinMaxScaler()

# %%
numerical_cols = list(x_train.select_dtypes(include=['int64', 'float64','int32']).columns)

# %%
x_train[numerical_cols] = scaler.fit_transform(x_train[numerical_cols])

# %%
x_test[numerical_cols] = scaler.transform(x_test[numerical_cols])

# %%
x_train.isnull().sum()
# Out:
# overall      0
# potential    0
# wage_eur     0
# age          0
# height_cm    0
#             ..
# cb           0
# rcb          0
# rb           0
# gk           0
# loyality     0
# Length: 116, dtype: int64

# %%
px.histogram(y_train)

# %%
sdfv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 sdfv
#
# NameError: name 'sdfv' is not defined

# %% [markdown]
# # linear regression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)

print('Training Score: ', lr.score(x_train, y_train))
print('test Score: ', lr.score(x_test, y_test))
##print('test Score: ', lr.score(x_test2, y_test2))
print('RMSE: ', np.sqrt(mean_squared_error(y_test, lr.predict(x_test))))
# Out:
# Training Score:  0.7302342141616744
# test Score:  0.7014707361831578
# RMSE:  3129592.217574698

# %% [markdown]
# # random forrest

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=5, max_depth = 200,  random_state=42)

rf.fit(x_train, y_train)

print('Training Score: ', rf.score(x_train, y_train))
print('test score: ', rf.score(x_test, y_test))
##print('test Score: ', lr.score(x_test2, y_test2))
print('RMSE: ', np.sqrt(mean_squared_error(y_test, rf.predict(x_test))))
# Out:
# Training Score:  0.9856928893992575
# test score:  0.9279682677812218
# RMSE:  1537291.505924179

# %% [markdown]
# ## grid search for random forrest

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
n_range = list(range(1,10))
depth_range = list(range(1,10))
param_grid = dict(n_estimators=n_range , max_depth = depth_range)
grid = GridSearchCV(rf , param_grid=param_grid, cv= 3 , scoring= "r2", return_train_score= False , verbose= 1)
grid_search = grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[166], line 8
#       6 param_grid = dict(n_estimators=n_range , max_depth = depth_range)
#       7 grid = GridSearchCV(rf , param_grid=param_grid, cv= 3 , scoring= "r2", return_train_score= False , verbose= 1)
# ----> 8 grid_search = grid.fit(x_train,y_train)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:1389, in GridSearchCV._run_search(self, evaluate_candidates)
#    1387 def _run_search(self, evaluate_candidates):
#    1388     """Search all candidates in param_grid"""
# -> 1389     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:822, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     814 if self.verbose > 0:
#     815     print(
#     816         "Fitting {0} folds for each of {1} candidates,"
#     817         " totalling {2} fits".format(
#     818             n_splits, n_candidates, n_candidates * n_splits
#     819         )
#     820     )
# --> 822 out = parallel(
#     823     delayed(_fit_and_score)(
#     824         clone(base_estimator),
#     825         X,
#     826         y,
#     827         train=train,
#     828         test=test,
#     829         parameters=parameters,
#     830         split_progress=(split_idx, n_splits),
#     831         candidate_progress=(cand_idx, n_candidates),
#     832         **fit_and_score_kwargs,
#     833     )
#     834     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     835         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     836     )
#     837 )
#     839 if len(out) < 1:
#     840     raise ValueError(
#     841         "No fits were performed. "
#     842         "Was the CV iterator empty? "
#     843         "Were there no candidates?"
#     844     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\parallel.py:1051, in Parallel.__call__(self, iterable)
#    1048 if self.dispatch_one_batch(iterator):
#    1049     self._iterating = self._original_iterator is not None
# -> 1051 while self.dispatch_one_batch(iterator):
#    1052     pass
#    1054 if pre_dispatch == "all" or n_jobs == 1:
#    1055     # The iterable was consumed all at once by the above for loop.
#    1056     # No need to wait for async callbacks to trigger to
#    1057     # consumption.
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\parallel.py:864, in Parallel.dispatch_one_batch(self, iterator)
#     862     return False
#     863 else:
# --> 864     self._dispatch(tasks)
#     865     return True
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\parallel.py:782, in Parallel._dispatch(self, batch)
#     780 with self._lock:
#     781     job_idx = len(self._jobs)
# --> 782     job = self._backend.apply_async(batch, callback=cb)
#     783     # A job can complete so quickly than its callback is
#     784     # called before we get here, causing self._jobs to
#     785     # grow. To ensure correct results ordering, .insert is
#     786     # used (rather than .append) in the following line
#     787     self._jobs.insert(job_idx, job)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\parallel.py:263, in BatchedCalls.__call__(self)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\parallel.py:263, in <listcomp>(.0)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_forest.py:474, in BaseForest.fit(self, X, y, sample_weight)
#     463 trees = [
#     464     self._make_estimator(append=False, random_state=random_state)
#     465     for i in range(n_more_estimators)
#     466 ]
#     468 # Parallel loop: we prefer the threading backend as the Cython code
#     469 # for fitting the trees is internally releasing the Python GIL
#     470 # making threading more efficient than multiprocessing in
#     471 # that case. However, for joblib 0.12+ we respect any
#     472 # parallel_backend contexts set at a higher level,
#     473 # since correctness does not rely on using threads.
# --> 474 trees = Parallel(
#     475     n_jobs=self.n_jobs,
#     476     verbose=self.verbose,
#     477     prefer="threads",
#     478 )(
#     479     delayed(_parallel_build_trees)(
#     480         t,
#     481         self.bootstrap,
#     482         X,
#     483         y,
#     484         sample_weight,
#     485         i,
#     486         len(trees),
#     487         verbose=self.verbose,
#     488         class_weight=self.class_weight,
#     489         n_samples_bootstrap=n_samples_bootstrap,
#     490     )
#     491     for i, t in enumerate(trees)
#     492 )
#     494 # Collect newly grown trees
#     495 self.estimators_.extend(trees)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\parallel.py:1051, in Parallel.__call__(self, iterable)
#    1048 if self.dispatch_one_batch(iterator):
#    1049     self._iterating = self._original_iterator is not None
# -> 1051 while self.dispatch_one_batch(iterator):
#    1052     pass
#    1054 if pre_dispatch == "all" or n_jobs == 1:
#    1055     # The iterable was consumed all at once by the above for loop.
#    1056     # No need to wait for async callbacks to trigger to
#    1057     # consumption.
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\parallel.py:864, in Parallel.dispatch_one_batch(self, iterator)
#     862     return False
#     863 else:
# --> 864     self._dispatch(tasks)
#     865     return True
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\parallel.py:782, in Parallel._dispatch(self, batch)
#     780 with self._lock:
#     781     job_idx = len(self._jobs)
# --> 782     job = self._backend.apply_async(batch, callback=cb)
#     783     # A job can complete so quickly than its callback is
#     784     # called before we get here, causing self._jobs to
#     785     # grow. To ensure correct results ordering, .insert is
#     786     # used (rather than .append) in the following line
#     787     self._jobs.insert(job_idx, job)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\parallel.py:263, in BatchedCalls.__call__(self)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\parallel.py:263, in <listcomp>(.0)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_forest.py:185, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     182     elif class_weight == "balanced_subsample":
#     183         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 185     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     186 else:
#     187     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\tree\_classes.py:1247, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1218 def fit(self, X, y, sample_weight=None, check_input=True):
#    1219     """Build a decision tree regressor from the training set (X, y).
#    1220
#    1221     Parameters
#    (...)
#    1244         Fitted estimator.
#    1245     """
# -> 1247     super().fit(
#    1248         X,
#    1249         y,
#    1250         sample_weight=sample_weight,
#    1251         check_input=check_input,
#    1252     )
#    1253     return self
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\tree\_classes.py:379, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     368 else:
#     369     builder = BestFirstTreeBuilder(
#     370         splitter,
#     371         min_samples_split,
#    (...)
#     376         self.min_impurity_decrease,
#     377     )
# --> 379 builder.build(self.tree_, X, y, sample_weight)
#     381 if self.n_outputs_ == 1 and is_classifier(self):
#     382     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
grid_search.best_params_

# %%
grid_search.best_score_

# %%
"""
for RF :
best parameter :{n_estimators=n_range: 1 , max_depth = depth_range : 1}
best score : 0.9245061291616669
"""

# %%
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': 200,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 5,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# # knn regresor

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_model= KNeighborsRegressor()
knn_model.fit(x_train,y_train)

print('Training Accuracy: ', knn_model.score(x_train, y_train))
print('validation Accuracy: ', knn_model.score(x_test, y_test))
print('test Accuracy: ', knn_model.score(x_test, y_test))
# Out:
# Training Accuracy:  0.7949424561054531
# validation Accuracy:  0.6268003973521066

# %% [markdown]
# ## find best K

# %%
train_acc , valid_acc = [] , []
for i in range(1,40,2) :
    knn_model = KNeighborsRegressor(n_neighbors=  i).fit(x_train , y_train)
    train_acc.append(knn_model.score(x_train , y_train))
    valid_acc.append(knn_model.score(x_test , y_test))
fig = px.line(x= range(1,40,2), y= [train_acc , valid_acc],title = "Accuracy" , legend_title = 'train vs valid')
fig.update_layout(xaxis_title = 'value of k' , yaxis_title = 'Accuracy' , legend_title = "train vs valid")
fig.data[0].name = 'Train acc'
fig.data[1].name = 'valid acc'
fig,show()

# %% [markdown]
# ## grid search for knn

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
knn= KNeighborsRegressor()
k_range = list(range(1,5))
leaf_size_range = list(range(1,10))
param_grid = dict(n_neighbors=k_range , leaf_size  = leaf_size_range)
grid = GridSearchCV(knn , param_grid=param_grid, cv= 3 , scoring= "r2", return_train_score= False , verbose= 1)
grid_search_knn = grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits

# %%
grid_search_knn.best_params_
# Out:
# {'leaf_size': 1, 'n_neighbors': 4}

# %%
grid_search_knn.best_score_
# Out:
# 0.6245061291616669

# %%
"""
for knn :
best parameter :{'leaf_size': 1, 'n_neighbors': 4}
best score : 0.6245061291616669
"""

# %% [markdown]
# ## xgboost

# %%
from xgboost import XGBRegressor
xgb_reg = XGBRegressor()
xgb_reg.fit(x_train, y_train)
print("Training accuracy: ", xgb_reg.score(x_train, y_train))
print("Testing accuracy: ", xgb_reg.score(x_test, y_test))
# Out:
# Training accuracy:  0.994393239087773
# Testing accuracy:  0.9348048183575922

# %% [markdown]
# ## SVR

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(x_train, y_train)
print("Training accuracy: ", svr.score(x_train, y_train))
print("Testing accuracy: ", svr.score(x_test, y_test))

# %% [markdown]
# ## grid search for SVR

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
svr_model = SVR()
epsilon_range = list(range(1,10))
param_grid = dict(epsilon =epsilon_range)
grid = GridSearchCV(svr_model , param_grid=param_grid, cv= 3 , scoring= "r2", return_train_score= False , verbose= 1)
grid_search = grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
svr = SVR()

# %%
epsilon_range = list(range(1,10))
param_grid = dict( epsilon = epsilon_range)
grid = GridSearchCV(SVR , param_grid=param_grid, cv= 3 , scoring= "r2", return_train_score= False , verbose= 1)
grid_search_knn = grid.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[165], line 4
#       2 param_grid = dict( epsilon = epsilon_range)
#       3 grid = GridSearchCV(SVR , param_grid=param_grid, cv= 3 , scoring= "r2", return_train_score= False , verbose= 1)
# ----> 4 grid_search_knn = grid.fit(x_train,y_train)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:789, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     786 cv_orig = check_cv(self.cv, y, classifier=is_classifier(estimator))
#     787 n_splits = cv_orig.get_n_splits(X, y, groups)
# --> 789 base_estimator = clone(self.estimator)
#     791 parallel = Parallel(n_jobs=self.n_jobs, pre_dispatch=self.pre_dispatch)
#     793 fit_and_score_kwargs = dict(
#     794     scorer=scorers,
#     795     fit_params=fit_params,
#    (...)
#     801     verbose=self.verbose,
#     802 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:73, in clone(estimator, safe)
#      71 else:
#      72     if isinstance(estimator, type):
# ---> 73         raise TypeError(
#      74             "Cannot clone object. "
#      75             + "You should provide an instance of "
#      76             + "scikit-learn estimator instead of a class."
#      77         )
#      78     else:
#      79         raise TypeError(
#      80             "Cannot clone object '%s' (type %s): "
#      81             "it does not seem to be a scikit-learn "
#      82             "estimator as it does not implement a "
#      83             "'get_params' method." % (repr(estimator), type(estimator))
#      84         )
#
# TypeError: Cannot clone object. You should provide an instance of scikit-learn estimator instead of a class.

# %% [markdown]
# ## Ridge

# %%
from sklearn.linear_model import Ridge
rid =Ridge(alpha=0.001)
rid.fit(x_train , y_train)
print ("train_score" , rid.score(x_train, y_train))
# Out:
# train_score 0.730237923230747

# %% [markdown]
# ## Lasso

# %%
from sklearn.linear_model import Lasso
lasso_reg= Lasso(max_iter=10000)
lasso_reg.fit(x_train, y_train)
print("Training accuracy: ", lasso_reg.score(x_train, y_train))
print("Testing accuracy: ", lasso_reg.score(x_test, y_test))
# Out:
# Training accuracy:  0.7302371909677741
# Testing accuracy:  0.7014489863236545
# C:\Users\HP.SXS04\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:634: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.236e+17, tolerance: 3.694e+14

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score
print(cross_val_score(rf , x_train , y_train , cv = 5))
# Out:
# [0.9215564  0.93473661 0.92755751 0.92329365 0.93725931]

# %%
## i found the data splited well

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=5)

X_train_pca = pca.fit_transform(x_train)
X_test_pca = pca.transform(x_test)

# %%
X_train_pca
# Out:
# array([[-0.69031323, -0.07775578,  0.16938292,  0.81845686, -0.16427643],
#        [ 1.99220296, -0.25691732, -0.7855513 ,  0.14152239,  0.24475482],
#        [-0.13725488, -0.66481756, -0.06668341,  0.31515254,  0.41273343],
#        ...,
#        [-1.30920665,  0.68334881,  0.42912308, -0.37327225, -1.18646556],
#        [-0.45831665, -0.53218241,  0.375454  , -0.77144713,  0.96877185],
#        [ 0.3441045 , -0.62726892, -1.03036229, -0.00259708, -0.23202663]])
